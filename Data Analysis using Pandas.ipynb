# %% [markdown]
# # Questions
# ### Q.1 Total no. of matches played in 2017
# ### Q.2 Total number of matches won ny Mumbai Indians
# ### Q.3 Find all the matches in 2017
# ### Q.4 Total no. mathes played at Wankhede Stadium
# ### Q.5 List Top 20 matches win by most runs
# ### Q.6 Top 10 matches won by most wickets
# ### Q.7 List all the matches in which 1st umpire was AY Dandekar
# ### Q.8 List all the matches in which Man of the match was CH Gayle
# ### Q.9 List all the matches in 2016 with date in which RCB had won the toss
# ### Q.10 List all the matches in 2016 with date in which RCB had won the match

# %% [markdown]
# ## axis0 for row and axis1 for column by defaults it understands axis0

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("data/matches.csv").head()   #To load file from the storage
#HEAD is used to show number of rows or lines of data,bydefault it shows 5 lines

# %%
df.rename({'city': 'City','date':"Date", 'team1':'Team1','team2': 'Team2','result': 'Result','player_of_match': "Man of the Match"},axis=1,inplace=True)
#To rename the column names and inplace=True to make changes in originaL data

# %%
df.head(2)
# Out:
#    id  season       City        Date                Team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          Team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   Man of the Match                                      venue         umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %%
df.drop("umpire2",axis=1)     #to delete one column
df.head(2)
# Out:
#    id  season       City        Date                Team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          Team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   Man of the Match                                      venue         umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %%
df.drop(["umpire2","umpire3"],axis=1).head(2)  #To delete more than one columns
df.head(2)
# Out:
#    id  season       City        Date                Team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          Team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   Man of the Match                                      venue         umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %%
df.dropna(how='any')    #To delete whole row which contains one or 'Na'
df.head(2)
# Out:
#    id  season       City        Date                Team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          Team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   Man of the Match                                      venue         umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %%
df.dropna(how='all')    #To delete whole row which contains complete row containing all the value named 'Na'
df.head(2)
# Out:
#    id  season       City        Date                Team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          Team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   Man of the Match                                      venue         umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %%
df.dropna(axis=1,how='all')    #To delete whole row which contains complete row containing all the value named 'Na'
df.head(2)
# Out:
#    id  season       City        Date                Team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          Team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   Man of the Match                                      venue         umpire1  \
# 0     Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1        SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %%
df['Date'].head(10)
# Out:
# 0    2017-04-05
# 1    2017-04-06
# 2    2017-04-07
# 3    2017-04-08
# 4    2017-04-08
# 5    2017-04-09
# 6    2017-04-09
# 7    2017-04-10
# 8    2017-04-11
# 9    2017-04-12
# Name: Date, dtype: object

# %%
df.iloc[::2,::2].head()
# Out:
#    id       City                        Team1                  toss_winner  \
# 0   1  Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 2   3     Rajkot                Gujarat Lions        Kolkata Knight Riders
# 4   5  Bangalore  Royal Challengers Bangalore  Royal Challengers Bangalore
# 6   7     Mumbai        Kolkata Knight Riders               Mumbai Indians
# 8   9       Pune             Delhi Daredevils       Rising Pune Supergiant
#
#    Result                       winner  win_by_wickets  \
# 0  normal          Sunrisers Hyderabad               0
# 2  normal        Kolkata Knight Riders              10
# 4  normal  Royal Challengers Bangalore               0
# 6  normal               Mumbai Indians               4
# 8  normal             Delhi Daredevils               0
#
#                                        venue    umpire2
# 0  Rajiv Gandhi International Stadium, Uppal   NJ Llong
# 2     Saurashtra Cricket Association Stadium  CK Nandan
# ...

# %%
df.loc[df['umpire1']=='AY Dandekar'].head()
# Out:
#     id  season       City        Date                  Team1  \
# 0    1    2017  Hyderabad  2017-04-05    Sunrisers Hyderabad
# 8    9    2017       Pune  2017-04-11       Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15  Kolkata Knight Riders
# 18  19    2017  Hyderabad  2017-04-17    Sunrisers Hyderabad
# 24  25    2017       Pune  2017-04-22    Sunrisers Hyderabad
#
#                           Team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 24       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#     Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.loc[df['umpire1']=='AY Dandekar'].head()
# Out:
#     id  season       City        Date                  Team1  \
# 0    1    2017  Hyderabad  2017-04-05    Sunrisers Hyderabad
# 8    9    2017       Pune  2017-04-11       Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15  Kolkata Knight Riders
# 18  19    2017  Hyderabad  2017-04-17    Sunrisers Hyderabad
# 24  25    2017       Pune  2017-04-22    Sunrisers Hyderabad
#
#                           Team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 24       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#     Result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.loc[df['umpire1']=='AY Dandekar'][10::2].head()
# Out:
#       id  season       City        Date                        Team1  \
# 604  605    2016       Pune  2016-05-01      Rising Pune Supergiants
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
#
#               Team2     toss_winner toss_decision  Result  dl_applied  \
# 604  Mumbai Indians  Mumbai Indians         field  normal           0
# 619   Gujarat Lions   Gujarat Lions         field  normal           0
#
#                           winner  win_by_runs  win_by_wickets  \
# 604               Mumbai Indians            0               8
# 619  Royal Challengers Bangalore          144               0
#
#     Man of the Match                                    venue      umpire1  \
# 604        RG Sharma  Maharashtra Cricket Association Stadium  AY Dandekar
# 619   AB de Villiers                    M Chinnaswamy Stadium  AY Dandekar
#
#        umpire2 umpire3
# 604  RJ Tucker     NaN
# 619  VK Sharma     NaN

# %%
df.loc[df['City']=='Kolkata',['City','toss_decision','toss_winner']].head()
# Out:
#        City toss_decision                  toss_winner
# 10  Kolkata         field        Kolkata Knight Riders
# 13  Kolkata         field          Sunrisers Hyderabad
# 22  Kolkata         field                Gujarat Lions
# 26  Kolkata         field  Royal Challengers Bangalore
# 30  Kolkata         field        Kolkata Knight Riders

# %%
x = df.loc[df['Man of the Match'] =='CH Gayle',['Man of the Match','Team1']]

# %%
len(x)
# Out:
# 20

# %%
df.loc[(df['winner']== 'Royal Challengers Bangalore') & (df['season']==2016)]
# Out:
#       id  season        City        Date                        Team1  \
# 579  580    2016   Bangalore  2016-04-12  Royal Challengers Bangalore
# 591  592    2016        Pune  2016-04-22  Royal Challengers Bangalore
# 610  611    2016   Bangalore  2016-05-07      Rising Pune Supergiants
# 614  615    2016  Chandigarh  2016-05-09  Royal Challengers Bangalore
# 619  620    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 623  624    2016     Kolkata  2016-05-16        Kolkata Knight Riders
# 625  626    2016   Bangalore  2016-05-18  Royal Challengers Bangalore
# 631  632    2016      Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016   Bangalore  2016-05-24                Gujarat Lions
#
#                            Team2                  toss_winner toss_decision  \
# 579          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 591      Rising Pune Supergiants      Rising Pune Supergiants         field
# ...

# %%
df.loc[(df['winner']== 'Royal Challengers Bangalore') & (df['season']==2016)  & (df['toss_winner'] == 'Royal Challengers Bangalore')]
# Out:
#       id  season       City        Date                    Team1  \
# 610  611    2016  Bangalore  2016-05-07  Rising Pune Supergiants
# 623  624    2016    Kolkata  2016-05-16    Kolkata Knight Riders
# 631  632    2016     Raipur  2016-05-22         Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24            Gujarat Lions
#
#                            Team2                  toss_winner toss_decision  \
# 610  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 623  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      Result  dl_applied                       winner  win_by_runs  \
# 610  normal           0  Royal Challengers Bangalore            0
# 623  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.loc[(df['winner']== 'Royal Challengers Bangalore') & (df['season']==2016)  & (df['toss_winner'] == 'Royal Challengers Bangalore'),["Team1","Team2","Match of the Match"]]
# Out:
#                        Team1                        Team2  Match of the Match
# 610  Rising Pune Supergiants  Royal Challengers Bangalore                 NaN
# 623    Kolkata Knight Riders  Royal Challengers Bangalore                 NaN
# 631         Delhi Daredevils  Royal Challengers Bangalore                 NaN
# 632            Gujarat Lions  Royal Challengers Bangalore                 NaN

# %%
df.sort_values(by="win_by_runs",ascending=False).head()
# Out:
#       id  season       City        Date                        Team1  \
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
#
#                            Team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# 619                Gujarat Lions                Gujarat Lions         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 556              Kings XI Punjab              Kings XI Punjab         field
# 410                Pune Warriors                Pune Warriors         field
#
#      Result  dl_applied                       winner  win_by_runs  \
# ...

# %%
y = df.loc[df["venue"]=="Wankhede Stadium"]
len(y)
# Out:
# 66
